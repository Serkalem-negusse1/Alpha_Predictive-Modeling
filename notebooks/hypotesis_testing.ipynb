# %% [markdown]
# # Hypothesis Testing for Claims and Premiums

# %%
import os
print(os.getcwd())
import sys
sys.path.append(r'.../scripts')
from ab_Hypothesis_testing import HypothesisTesting
# Out:
# c:\Alpha_Predictive-Modeling\notebooks

# %% [markdown]
# Load Libraries

# %%
import pandas as pd

# %% [markdown]
# Load Dataset

# %%
data = pd.read_csv("... data/insurance_data.csv")

# %%
# Hypothesis Testing
tester = HypothesisTesting(data)

# %%
# ANOVA: Claims Across Provinces
print(tester.test_claims_across_provinces())
# Out:
# {'Test': 'ANOVA', 'Null Hypothesis': 'No significant claims differences across provinces', 'F-Statistic': np.float64(8.626482565483611), 'p-Value': np.float64(0.0001930246778774567), 'Reject Null': np.True_}

# %%
# T-Test: Claims Across Genders
print(tester.test_claims_difference_gender())
# Out:
# {'Test': 'T-Test', 'Null Hypothesis': 'No significant claims differences between genders', 'T-Statistic': np.float64(3.5693545588418787), 'p-Value': np.float64(0.00037512158401762627), 'Reject Null': np.True_}

# %%
# Visualize Distributions
tester.visualize_distributions()
