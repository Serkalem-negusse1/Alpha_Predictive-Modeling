# %% [markdown]
# Getting working directory

# %%
import os
print(os.getcwd())
# Out:
# c:\Alpha_Predictive-Modeling\notebooks

# %% [markdown]
# Calling absolute path

# %%
import sys
sys.path.append(r'c:/Alpha_Predictive-Modeling/scripts')
from eda import pmEDA

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import the EDA class

# %%
from eda import pmEDA

# %% [markdown]
# # Initialize the EDA class with the dataset path

# %%
eda = pmEDA(file_path="E:/10Academy/Data03/processed_data.csv")

# %% [markdown]
# # Step 1: Load the dataset

# %%
df = eda.load_data()
# Out:
# c:\Alpha_Predictive-Modeling/scripts\eda.py:14: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv(self.file_path)
# Data loaded successfully.

# %% [markdown]
# # Step 2: Data summary

# %%
eda.data_summary()
# Out:
# Descriptive Statistics:
#        UnderwrittenCoverID      PolicyID        Gender      Province  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  1.000098e+06
# mean          1.048175e+05  7.956682e+03  1.939847e+00  3.938470e+00
# std           6.329371e+04  5.290039e+03  2.650084e-01  2.390646e+00
# min           1.000000e+00  1.400000e+01  0.000000e+00  0.000000e+00
# 25%           5.514300e+04  4.500000e+03  2.000000e+00  2.000000e+00
# 50%           9.408300e+04  7.071000e+03  2.000000e+00  3.000000e+00
# 75%           1.391900e+05  1.107700e+04  2.000000e+00  6.000000e+00
# max           3.011750e+05  2.324600e+04  2.000000e+00  8.000000e+00
#
#          PostalCode        mmcode   VehicleType  RegistrationYear  \
# count  1.000098e+06  1.000098e+06  1.000098e+06      1.000098e+06
# mean   3.020601e+03  5.487965e+07  3.913366e+00      2.010225e+03
# std    2.649854e+03  1.360189e+07  3.732324e-01      3.261391e+00
# ...

# %% [markdown]
# # Step 3: Check for missing values

# %%
eda.check_missing()
# Out:
# Missing Values:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                              0
# AccountType                       0
# MaritalStatus                     0
# Gender                            0
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                            0
# VehicleType                       0
# RegistrationYear                  0
# make                              0
# Model                             0
# Cylinders                         0
# cubiccapacity                     0
# ...

# %% [markdown]
# # Step 4: Univariate analysis on 'TotalPremium'

# %%
eda.univariate_analysis("TotalPremium")

# %% [markdown]
# # Step 5: Bivariate analysis between 'TotalPremium' and 'TotalClaims'

# %%
eda.bivariate_analysis("TotalPremium", "TotalClaims")

# %% [markdown]
# # Outlier Detection

# %%
sns.boxplot(data=df, y="TotalPremium")
plt.title("Outliers in TotalPremium")
plt.show()
